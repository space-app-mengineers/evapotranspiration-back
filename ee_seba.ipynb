# %%
import ee
ee.Authenticate()
ee.Initialize()

# %%
import ee
ee.Initialize()

# Define a region of interest
roi = ee.Geometry.Point([-122.262, 37.8719])

# Load Landsat 8 image collection, filter by date and region
landsat = ee.ImageCollection("LANDSAT/LC08/C02/T1_TOA").filterDate('2024-01-01', '2024-09-20').filterBounds(roi)

# Select specific bands (e.g., B4 (red), B5 (near-infrared))
bands = landsat.select(['B1', 'B2', 'B3', 'B4', 'B5', 'B6', 'B7', 'B8', 'B9', 'B10', 'B11'])

# Get the first image
image = bands.first()

# Print image info
print(image.getInfo())
# Out:
# {'type': 'Image', 'bands': [{'id': 'B1', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7671, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 462885, 0, -30, 4264215]}, {'id': 'B2', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7671, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 462885, 0, -30, 4264215]}, {'id': 'B3', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7671, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 462885, 0, -30, 4264215]}, {'id': 'B4', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7671, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 462885, 0, -30, 4264215]}, {'id': 'B5', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7671, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 462885, 0, -30, 4264215]}, {'id': 'B6', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7671, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 462885, 0, -30, 4264215]}, {'id': 'B7', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7671, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 462885, 0, -30, 4264215]}, {'id': 'B8', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [15341, 15601], 'crs': 'EPSG:32610', 'crs_transform': [15, 0, 462892.5, 0, -15, 4264207.5]}, {'id': 'B9', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7671, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 462885, 0, -30, 4264215]}, {'id': 'B10', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7671, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 462885, 0, -30, 4264215]}, {'id': 'B11', 'data_type': {'type': 'PixelType', 'precision': 'float'}, 'dimensions': [7671, 7801], 'crs': 'EPSG:32610', 'crs_transform': [30, 0, 462885, 0, -30, 4264215]}], 'version': 1727968519583326, 'id': 'LANDSAT/LC08/C02/T1_TOA/LC08_044034_20240109', 'properties': {'RADIANCE_MULT_BAND_5': 0.0063218, 'RADIANCE_MULT_BAND_6': 0.0015722, 'RADIANCE_MULT_BAND_3': 0.012251, 'RADIANCE_MULT_BAND_4': 0.010331, 'RADIANCE_MULT_BAND_1': 0.012983, 'RADIANCE_MULT_BAND_2': 0.013295, 'WRS_TYPE': 2, 'K2_CONSTANT_BAND_11': 1201.1442, 'K2_CONSTANT_BAND_10': 1321.0789, 'system:footprint': {'type': 'LinearRing', 'coordinates': [[-121.34164353953932, 36.40824273338435], [-121.3397373788569, 36.40821625603398], [-121.33823818832836, 36.41273181675506], [-121.21197444935082, 36.822843179675544], [-121.08471597874684, 37.23133396149937], [-120.97536754838012, 37.579674059642095], [-120.92650189316845, 37.73458766937677], [-120.87262699483314, 37.90472293549153], [-120.83924450466218, 38.009888334026456], [-120.80284033509854, 38.12524173974509], [-120.80278879454752, 38.12696010179992], [-122.38779131503289, 38.42908525395369], [-122.92529659690108, 38.526138377521896], [-122.92821523550184, 38.51775751696459], [-122.93050256944645, 38.51059229799871], [-123.41465897306976, 36.80766641025848], [-123.41464930453648, 36.8058607107622], [-122.83309401036267, 36.69834760768759], [-121.4326285866192, 36.426512380939705], [-121.34164353953932, 36.40824273338435]]}, 'REFLECTIVE_SAMPLES': 7671, 'SUN_AZIMUTH': 156.77004882, 'DATA_SOURCE_TIRS_STRAY_LIGHT_CORRECTION': 'TIRS', 'DATE_ACQUIRED': '2024-01-09', 'ELLIPSOID': 'WGS84', 'STATION_ID': 'LGN', 'RESAMPLING_OPTION': 'CUBIC_CONVOLUTION', 'ORIENTATION': 'NORTH_UP', 'WRS_ROW': 34, 'RADIANCE_MULT_BAND_9': 0.0024707, 'TARGET_WRS_ROW': 34, 'RADIANCE_MULT_BAND_7': 0.00052991, 'RADIANCE_MULT_BAND_8': 0.011691, 'IMAGE_QUALITY_TIRS': 9, 'TRUNCATION_OLI': 'UPPER', 'CLOUD_COVER': 76.07, 'COLLECTION_CATEGORY': 'T1', 'GRID_CELL_SIZE_REFLECTIVE': 30, 'CLOUD_COVER_LAND': 80.75, 'GEOMETRIC_RMSE_MODEL': 8.283, 'COLLECTION_NUMBER': 2, 'IMAGE_QUALITY_OLI': 9, 'LANDSAT_SCENE_ID': 'LC80440342024009LGN00', 'WRS_PATH': 44, 'PANCHROMATIC_SAMPLES': 15341, 'PANCHROMATIC_LINES': 15601, 'GEOMETRIC_RMSE_MODEL_Y': ...

# %%
import folium

vis_params = {
    'min': 0,
    'max': 0.3,
    'bands': ['B3', 'B4', 'B5',],
}

# Create a folium map centered at the region of interest
map_center = [-33.522464, -70.568975] 
m = folium.Map(location=map_center, zoom_start=12)

# Add the image layer to the map
map_id_dict = ee.Image(image).getMapId(vis_params)
folium.TileLayer(
    tiles=map_id_dict['tile_fetcher'].url_format,
    attr='Google Earth Engine',
    name='Landsat 8 True Color',
    overlay=True,
    control=True
).add_to(m)

# Add layer control
m.add_child(folium.LayerControl())
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_894a3373ce2c2bd39a31a4bd8edf642e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_894a3373ce2c2bd39a31a4bd8edf642e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_894a3373ce2c2bd39a31a4bd8edf642e = L.map(
#                 &quot;map_894a3373ce2c2bd39a31a4bd8edf642e&quot;,
#                 {
#                     center: [-33.522464, -70.568975],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e1780d5743cfd3cd22ada75687b7272 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6e1780d5743cfd3cd22ada75687b7272.addTo(map_894a3373ce2c2bd39a31a4bd8edf642e);
#
#
#             var tile_layer_3199c5338eb37507a4256b80e3552e56 = L.tileLayer(
#                 &quot;https://earthengine.googleapis.com/v1/projects/465119630439/maps/80946f79bb5d3a079b56e5f81e5a8bd7-c8075f2e9f63bc706ed1cd00620cba18/tiles/{z}/{x}/{y}&quot;,
#                 {&quot;attribution&quot;: &quot;Google Earth Engine&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3199c5338eb37507a4256b80e3552e56.addTo(map_894a3373ce2c2bd39a31a4bd8edf642e);
#
#
#             var layer_control_73456414e716e88782cd9769935e8b03_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_6e1780d5743cfd3cd22ada75687b7272,
#                 },
#                 overlays :  {
#                     &quot;Landsat 8 True Color&quot; : tile_layer_3199c5338eb37507a4256b80e3552e56,
#                 },
#             };
#             let layer_control_73456414e716e88782cd9769935e8b03 = L.control.layers(
#                 layer_control_73456414e716e88782cd9769935e8b03_layers.base_layers,
#                 layer_control_73456414e716e88782cd9769935e8b03_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: true, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_894a3373ce2c2bd39a31a4bd8edf642e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
